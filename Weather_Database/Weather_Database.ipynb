# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
#cities
# Out:
# 760

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_conditions = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Conditions": city_current_conditions,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kalmunai
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | kunyang
# Processing Record 12 of Set 1 | carballo
# Processing Record 13 of Set 1 | marsa matruh
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | tura
# Processing Record 19 of Set 1 | salalah
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | fairbanks
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | guerrero negro
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | llandrindod wells
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 1 | palembang
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | akyab
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | tamandare
# Processing Record 37 of Set 1 | port lincoln
# Processing Record 38 of Set 1 | krasnorechenskiy
# Processing Record 39 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | yarmouth
# Processing Record 42 of Set 1 | canberra
# Processing Record 43 of Set 1 | kamenka
# Processing Record 44 of Set 1 | pamekasan
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | ambovombe
# Processing Record 47 of Set 1 | padang
# Processing Record 48 of Set 1 | rawang
# Processing Record 49 of Set 1 | goure
# Processing Record 50 of Set 1 | isangel
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | auki
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | dingle
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | farafenni
# Processing Record 9 of Set 2 | ayr
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | preobrazheniye
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | iruma
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | mandalgovi
# Processing Record 18 of Set 2 | altinho
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 21 of Set 2 | leningradskiy
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | bantogon
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | paso de ovejas
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | nishihara
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | flinders
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | antalaha
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | armidale
# Processing Record 39 of Set 2 | sorland
# Processing Record 40 of Set 2 | praia da vitoria
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | peterhead
# Processing Record 43 of Set 2 | naron
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | ouahigouya
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | faya
# Processing Record 48 of Set 2 | north platte
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | lata
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | vila franca do campo
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | olinda
# Processing Record 5 of Set 3 | komsomolskiy
# Processing Record 6 of Set 3 | sola
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | huilong
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | bathsheba
# Processing Record 11 of Set 3 | karasjok
# Processing Record 12 of Set 3 | pandan
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | fortuna
# Processing Record 15 of Set 3 | grindavik
# Processing Record 16 of Set 3 | kaeo
# Processing Record 17 of Set 3 | panjakent
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | lasa
# Processing Record 20 of Set 3 | toowoomba
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | huejuquilla el alto
# Processing Record 24 of Set 3 | puerto penasco
# Processing Record 25 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 26 of Set 3 | ballina
# Processing Record 27 of Set 3 | cayenne
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | san policarpo
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | hervey bay
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | barabai
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | bandarbeyla
# Processing Record 41 of Set 3 | greytown
# Processing Record 42 of Set 3 | hargeysa
# Processing Record 43 of Set 3 | tautira
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | ulaanbaatar
# Processing Record 46 of Set 3 | umm lajj
# Processing Record 47 of Set 3 | trelew
# Processing Record 48 of Set 3 | praia
# Processing Record 49 of Set 3 | aklavik
# Processing Record 50 of Set 3 | port macquarie
# Processing Record 1 of Set 4 | juba
# Processing Record 2 of Set 4 | poum
# Processing Record 3 of Set 4 | pirapora
# Processing Record 4 of Set 4 | santiago del estero
# Processing Record 5 of Set 4 | pospelikha
# Processing Record 6 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 4 | calabozo
# Processing Record 8 of Set 4 | umm kaddadah
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | taoudenni
# Processing Record 11 of Set 4 | krian
# Processing Record 12 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 13 of Set 4 | asau
# Processing Record 14 of Set 4 | saint-pierre
# Processing Record 15 of Set 4 | bombay
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | kharan
# Processing Record 18 of Set 4 | wegorzewo
# Processing Record 19 of Set 4 | kosh-agach
# Processing Record 20 of Set 4 | srednekolymsk
# Processing Record 21 of Set 4 | cumberland
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | mormugao
# Processing Record 25 of Set 4 | namatanai
# Processing Record 26 of Set 4 | petropavl
# Processing Record 27 of Set 4 | tiksi
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | torbay
# Processing Record 31 of Set 4 | elmina
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | yarega
# Processing Record 35 of Set 4 | nicoya
# Processing Record 36 of Set 4 | mantua
# Processing Record 37 of Set 4 | glens falls
# Processing Record 38 of Set 4 | vostok
# Processing Record 39 of Set 4 | qafsah
# City not found. Skipping...
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | pemberton
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | itai
# Processing Record 44 of Set 4 | sao joao da barra
# Processing Record 45 of Set 4 | sal rei
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | shimoda
# Processing Record 49 of Set 4 | mocuba
# Processing Record 50 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 5 | karagay
# Processing Record 2 of Set 5 | agirish
# Processing Record 3 of Set 5 | north battleford
# Processing Record 4 of Set 5 | barcelona
# Processing Record 5 of Set 5 | lompoc
# Processing Record 6 of Set 5 | pangnirtung
# Processing Record 7 of Set 5 | nikolskoye
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | coahuayana
# Processing Record 10 of Set 5 | tucuma
# Processing Record 11 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 5 | viedma
# Processing Record 13 of Set 5 | yulara
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | ixtapa
# Processing Record 16 of Set 5 | souillac
# Processing Record 17 of Set 5 | rzeszow
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 5 | pevek
# Processing Record 21 of Set 5 | macapa
# Processing Record 22 of Set 5 | homer
# Processing Record 23 of Set 5 | faizpur
# Processing Record 24 of Set 5 | cabo san lucas
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | crotone
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 29 of Set 5 | vredendal
# Processing Record 30 of Set 5 | arlit
# Processing Record 31 of Set 5 | along
# Processing Record 32 of Set 5 | saint-augustin
# Processing Record 33 of Set 5 | fort walton beach
# Processing Record 34 of Set 5 | richards bay
# Processing Record 35 of Set 5 | huangchuan
# Processing Record 36 of Set 5 | hambantota
# Processing Record 37 of Set 5 | valparaiso
# Processing Record 38 of Set 5 | chulumani
# Processing Record 39 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 5 | texarkana
# Processing Record 41 of Set 5 | bowen
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | tinskoy
# Processing Record 44 of Set 5 | ahipara
# Processing Record 45 of Set 5 | ternate
# Processing Record 46 of Set 5 | aksay
# Processing Record 47 of Set 5 | puerto del rosario
# Processing Record 48 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 5 | bengkulu
# Processing Record 50 of Set 5 | tasiilaq
# Processing Record 1 of Set 6 | obo
# Processing Record 2 of Set 6 | mudbidri
# Processing Record 3 of Set 6 | puteyets
# Processing Record 4 of Set 6 | wajir
# Processing Record 5 of Set 6 | mount isa
# Processing Record 6 of Set 6 | rock sound
# Processing Record 7 of Set 6 | lagoa
# Processing Record 8 of Set 6 | napier
# Processing Record 9 of Set 6 | kerman
# Processing Record 10 of Set 6 | saint-georges
# Processing Record 11 of Set 6 | kutum
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | jaciara
# Processing Record 14 of Set 6 | burica
# City not found. Skipping...
# Processing Record 15 of Set 6 | port-cartier
# Processing Record 16 of Set 6 | comodoro rivadavia
# Processing Record 17 of Set 6 | kuytun
# Processing Record 18 of Set 6 | anadyr
# Processing Record 19 of Set 6 | skibbereen
# Processing Record 20 of Set 6 | cockburn town
# Processing Record 21 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 6 | waterloo
# Processing Record 23 of Set 6 | okha
# Processing Record 24 of Set 6 | baracoa
# Processing Record 25 of Set 6 | jiexiu
# Processing Record 26 of Set 6 | le mans
# Processing Record 27 of Set 6 | amberley
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | kollumerland
# City not found. Skipping...
# Processing Record 30 of Set 6 | sug-aksy
# City not found. Skipping...
# Processing Record 31 of Set 6 | iqaluit
# Processing Record 32 of Set 6 | saint-joseph
# Processing Record 33 of Set 6 | jalu
# Processing Record 34 of Set 6 | adrar
# Processing Record 35 of Set 6 | kirakira
# Processing Record 36 of Set 6 | san pedro
# Processing Record 37 of Set 6 | yakeshi
# Processing Record 38 of Set 6 | general roca
# Processing Record 39 of Set 6 | nizwa
# Processing Record 40 of Set 6 | fuling
# Processing Record 41 of Set 6 | moose factory
# Processing Record 42 of Set 6 | oktyabrskiy
# Processing Record 43 of Set 6 | dwarka
# Processing Record 44 of Set 6 | mabaruma
# Processing Record 45 of Set 6 | ancud
# Processing Record 46 of Set 6 | alyangula
# Processing Record 47 of Set 6 | saskylakh
# Processing Record 48 of Set 6 | marrakesh
# Processing Record 49 of Set 6 | lethem
# Processing Record 50 of Set 6 | esil
# Processing Record 1 of Set 7 | buala
# Processing Record 2 of Set 7 | muros
# Processing Record 3 of Set 7 | saraza
# Processing Record 4 of Set 7 | reefton
# City not found. Skipping...
# Processing Record 5 of Set 7 | esperance
# Processing Record 6 of Set 7 | puro
# Processing Record 7 of Set 7 | kungurtug
# Processing Record 8 of Set 7 | santa cruz
# Processing Record 9 of Set 7 | macusani
# Processing Record 10 of Set 7 | denia
# Processing Record 11 of Set 7 | mahajanga
# Processing Record 12 of Set 7 | port-gentil
# Processing Record 13 of Set 7 | bulungu
# Processing Record 14 of Set 7 | visby
# Processing Record 15 of Set 7 | elizabeth city
# Processing Record 16 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 7 | narsaq
# Processing Record 19 of Set 7 | pa sang
# Processing Record 20 of Set 7 | orange
# Processing Record 21 of Set 7 | uvalde
# Processing Record 22 of Set 7 | rawson
# Processing Record 23 of Set 7 | the valley
# Processing Record 24 of Set 7 | gagnoa
# Processing Record 25 of Set 7 | himora
# City not found. Skipping...
# Processing Record 26 of Set 7 | impfondo
# Processing Record 27 of Set 7 | half moon bay
# Processing Record 28 of Set 7 | ludwigslust
# Processing Record 29 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 30 of Set 7 | nhulunbuy
# Processing Record 31 of Set 7 | gari
# Processing Record 32 of Set 7 | bajil
# Processing Record 33 of Set 7 | hovd
# Processing Record 34 of Set 7 | bethel
# Processing Record 35 of Set 7 | santa lucia
# Processing Record 36 of Set 7 | tall kayf
# Processing Record 37 of Set 7 | carauari
# Processing Record 38 of Set 7 | leshukonskoye
# Processing Record 39 of Set 7 | luancheng
# Processing Record 40 of Set 7 | fria
# Processing Record 41 of Set 7 | fredericton
# Processing Record 42 of Set 7 | bambanglipuro
# Processing Record 43 of Set 7 | nioro
# Processing Record 44 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 7 | taltal
# Processing Record 46 of Set 7 | mahanoro
# Processing Record 47 of Set 7 | bubaque
# Processing Record 48 of Set 7 | radovis
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | port dover
# Processing Record 1 of Set 8 | jaypur
# Processing Record 2 of Set 8 | aswan
# Processing Record 3 of Set 8 | sokoni
# Processing Record 4 of Set 8 | orocue
# Processing Record 5 of Set 8 | sheridan
# Processing Record 6 of Set 8 | veraval
# Processing Record 7 of Set 8 | xapuri
# Processing Record 8 of Set 8 | lang son
# Processing Record 9 of Set 8 | krasnoselkup
# Processing Record 10 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 8 | port hardy
# Processing Record 12 of Set 8 | kamaishi
# Processing Record 13 of Set 8 | sergeyevka
# Processing Record 14 of Set 8 | shamary
# Processing Record 15 of Set 8 | nieuw amsterdam
# Processing Record 16 of Set 8 | lorengau
# Processing Record 17 of Set 8 | pio xii
# Processing Record 18 of Set 8 | chuguyevka
# Processing Record 19 of Set 8 | salmas
# Processing Record 20 of Set 8 | puerto quijarro
# Processing Record 21 of Set 8 | cururupu
# Processing Record 22 of Set 8 | abasolo
# Processing Record 23 of Set 8 | qaqortoq
# Processing Record 24 of Set 8 | mehamn
# Processing Record 25 of Set 8 | ohara
# Processing Record 26 of Set 8 | iquique
# Processing Record 27 of Set 8 | byron bay
# Processing Record 28 of Set 8 | haines junction
# Processing Record 29 of Set 8 | ostrovnoy
# Processing Record 30 of Set 8 | sioux lookout
# Processing Record 31 of Set 8 | sakakah
# Processing Record 32 of Set 8 | baykit
# Processing Record 33 of Set 8 | uyuni
# Processing Record 34 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 8 | mayo
# Processing Record 36 of Set 8 | baruun-urt
# Processing Record 37 of Set 8 | atar
# Processing Record 38 of Set 8 | opglabbeek
# Processing Record 39 of Set 8 | pasighat
# Processing Record 40 of Set 8 | santa fe
# Processing Record 41 of Set 8 | shu
# Processing Record 42 of Set 8 | hauterive
# Processing Record 43 of Set 8 | tungor
# Processing Record 44 of Set 8 | flin flon
# Processing Record 45 of Set 8 | kiruna
# Processing Record 46 of Set 8 | eirunepe
# Processing Record 47 of Set 8 | fontanka
# Processing Record 48 of Set 8 | mitu
# Processing Record 49 of Set 8 | san anselmo
# Processing Record 50 of Set 8 | middleton
# Processing Record 1 of Set 9 | morondava
# Processing Record 2 of Set 9 | cozumel
# Processing Record 3 of Set 9 | turukhansk
# Processing Record 4 of Set 9 | nizhneangarsk
# Processing Record 5 of Set 9 | rorvik
# Processing Record 6 of Set 9 | sena madureira
# Processing Record 7 of Set 9 | vestmannaeyjar
# Processing Record 8 of Set 9 | bouafle
# Processing Record 9 of Set 9 | caravelas
# Processing Record 10 of Set 9 | vidim
# Processing Record 11 of Set 9 | karatau
# Processing Record 12 of Set 9 | codrington
# Processing Record 13 of Set 9 | whitianga
# Processing Record 14 of Set 9 | kendari
# Processing Record 15 of Set 9 | quibor
# Processing Record 16 of Set 9 | leh
# Processing Record 17 of Set 9 | plover
# Processing Record 18 of Set 9 | xiongzhou
# Processing Record 19 of Set 9 | kupang
# Processing Record 20 of Set 9 | astoria
# Processing Record 21 of Set 9 | juneau
# Processing Record 22 of Set 9 | provideniya
# Processing Record 23 of Set 9 | ocampo
# Processing Record 24 of Set 9 | duma
# Processing Record 25 of Set 9 | vvedenskoye
# Processing Record 26 of Set 9 | sabla
# Processing Record 27 of Set 9 | santa cecilia
# Processing Record 28 of Set 9 | traverse city
# Processing Record 29 of Set 9 | herre
# Processing Record 30 of Set 9 | bulawayo
# Processing Record 31 of Set 9 | yokadouma
# Processing Record 32 of Set 9 | polis
# Processing Record 33 of Set 9 | zirandaro
# Processing Record 34 of Set 9 | luwuk
# Processing Record 35 of Set 9 | russell
# Processing Record 36 of Set 9 | cherkessk
# Processing Record 37 of Set 9 | howard springs
# Processing Record 38 of Set 9 | japura
# Processing Record 39 of Set 9 | palmer
# Processing Record 40 of Set 9 | teknaf
# Processing Record 41 of Set 9 | norton shores
# Processing Record 42 of Set 9 | dhidhdhoo
# Processing Record 43 of Set 9 | anlu
# Processing Record 44 of Set 9 | natal
# Processing Record 45 of Set 9 | gravdal
# Processing Record 46 of Set 9 | lisala
# Processing Record 47 of Set 9 | trebinje
# Processing Record 48 of Set 9 | beian
# Processing Record 49 of Set 9 | oranjemund
# Processing Record 50 of Set 9 | bairiki
# Processing Record 1 of Set 10 | freeport
# Processing Record 2 of Set 10 | derzhavinsk
# Processing Record 3 of Set 10 | parabel
# Processing Record 4 of Set 10 | mabama
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | airai
# Processing Record 7 of Set 10 | sibu
# Processing Record 8 of Set 10 | atikokan
# Processing Record 9 of Set 10 | kem
# Processing Record 10 of Set 10 | saint anthony
# Processing Record 11 of Set 10 | arrifes
# Processing Record 12 of Set 10 | siyabuswa
# Processing Record 13 of Set 10 | oranjestad
# Processing Record 14 of Set 10 | korla
# Processing Record 15 of Set 10 | broken hill
# Processing Record 16 of Set 10 | alta floresta
# Processing Record 17 of Set 10 | chifeng
# Processing Record 18 of Set 10 | pokosnoye
# Processing Record 19 of Set 10 | nanortalik
# Processing Record 20 of Set 10 | kopervik
# Processing Record 21 of Set 10 | kochi
# Processing Record 22 of Set 10 | necochea
# Processing Record 23 of Set 10 | gold coast
# Processing Record 24 of Set 10 | kourou
# Processing Record 25 of Set 10 | lavrentiya
# Processing Record 26 of Set 10 | bud
# Processing Record 27 of Set 10 | quatre cocos
# Processing Record 28 of Set 10 | brainerd
# Processing Record 29 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 10 | guia lopes da laguna
# Processing Record 31 of Set 10 | olga
# Processing Record 32 of Set 10 | mitsamiouli
# Processing Record 33 of Set 10 | stromness
# Processing Record 34 of Set 10 | urucara
# Processing Record 35 of Set 10 | aykhal
# Processing Record 36 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 10 | chumikan
# Processing Record 38 of Set 10 | charters towers
# Processing Record 39 of Set 10 | yamada
# Processing Record 40 of Set 10 | luanda
# Processing Record 41 of Set 10 | grand gaube
# Processing Record 42 of Set 10 | atambua
# Processing Record 43 of Set 10 | usinsk
# Processing Record 44 of Set 10 | nelson bay
# Processing Record 45 of Set 10 | bontang
# Processing Record 46 of Set 10 | dunedin
# Processing Record 47 of Set 10 | inirida
# Processing Record 48 of Set 10 | geraldton
# Processing Record 49 of Set 10 | karatu
# Processing Record 50 of Set 10 | soe
# Processing Record 1 of Set 11 | inuvik
# Processing Record 2 of Set 11 | miraflores
# Processing Record 3 of Set 11 | pindiga
# Processing Record 4 of Set 11 | kyzyl-suu
# Processing Record 5 of Set 11 | ngunguru
# Processing Record 6 of Set 11 | port keats
# Processing Record 7 of Set 11 | kommunar
# Processing Record 8 of Set 11 | ambikapur
# Processing Record 9 of Set 11 | bitung
# Processing Record 10 of Set 11 | astorga
# Processing Record 11 of Set 11 | kalaleh
# Processing Record 12 of Set 11 | tuatapere
# Processing Record 13 of Set 11 | rundu
# Processing Record 14 of Set 11 | ampanihy
# Processing Record 15 of Set 11 | sabzevar
# Processing Record 16 of Set 11 | dharchula
# Processing Record 17 of Set 11 | lucea
# Processing Record 18 of Set 11 | vadnagar
# Processing Record 19 of Set 11 | meulaboh
# Processing Record 20 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 11 | kishtwar
# Processing Record 22 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 23 of Set 11 | talcahuano
# Processing Record 24 of Set 11 | yar-sale
# Processing Record 25 of Set 11 | kardla
# Processing Record 26 of Set 11 | cabedelo
# Processing Record 27 of Set 11 | puquio
# Processing Record 28 of Set 11 | ouadda
# Processing Record 29 of Set 11 | ilulissat
# Processing Record 30 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 11 | road town
# Processing Record 32 of Set 11 | marienburg
# Processing Record 33 of Set 11 | kushalgarh
# Processing Record 34 of Set 11 | qasigiannguit
# Processing Record 35 of Set 11 | falaleu
# City not found. Skipping...
# Processing Record 36 of Set 11 | sorong
# Processing Record 37 of Set 11 | panzhihua
# Processing Record 38 of Set 11 | marawi
# Processing Record 39 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 11 | nalut
# Processing Record 41 of Set 11 | svetlogorsk
# Processing Record 42 of Set 11 | takapau
# Processing Record 43 of Set 11 | palladam
# Processing Record 44 of Set 11 | luwingu
# Processing Record 45 of Set 11 | san quintin
# Processing Record 46 of Set 11 | north branch
# Processing Record 47 of Set 11 | san andres
# Processing Record 48 of Set 11 | mogwase
# Processing Record 49 of Set 11 | lima
# Processing Record 50 of Set 11 | ailigandi
# Processing Record 1 of Set 12 | katsuura
# Processing Record 2 of Set 12 | mumford
# Processing Record 3 of Set 12 | husavik
# Processing Record 4 of Set 12 | mgachi
# Processing Record 5 of Set 12 | belaya gora
# Processing Record 6 of Set 12 | paita
# Processing Record 7 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 12 | gwembe
# Processing Record 9 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 12 | morros
# Processing Record 11 of Set 12 | colac
# Processing Record 12 of Set 12 | kraste
# City not found. Skipping...
# Processing Record 13 of Set 12 | sao sepe
# Processing Record 14 of Set 12 | mindelo
# Processing Record 15 of Set 12 | rocha
# Processing Record 16 of Set 12 | beringovskiy
# Processing Record 17 of Set 12 | lapa
# Processing Record 18 of Set 12 | seaford
# Processing Record 19 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 12 | batagay
# Processing Record 21 of Set 12 | kawalu
# Processing Record 22 of Set 12 | saint-leu
# Processing Record 23 of Set 12 | fountain hills
# Processing Record 24 of Set 12 | presidencia roque saenz pena
# Processing Record 25 of Set 12 | lanzhou
# Processing Record 26 of Set 12 | muncar
# Processing Record 27 of Set 12 | zeya
# Processing Record 28 of Set 12 | samarai
# Processing Record 29 of Set 12 | amparo
# Processing Record 30 of Set 12 | chicama
# Processing Record 31 of Set 12 | methoni
# Processing Record 32 of Set 12 | tymovskoye
# Processing Record 33 of Set 12 | sinnamary
# Processing Record 34 of Set 12 | mezen
# Processing Record 35 of Set 12 | emerald
# Processing Record 36 of Set 12 | omsukchan
# Processing Record 37 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 38 of Set 12 | challapata
# Processing Record 39 of Set 12 | tessalit
# Processing Record 40 of Set 12 | rotherham
# Processing Record 41 of Set 12 | piacabucu
# Processing Record 42 of Set 12 | kilindoni
# Processing Record 43 of Set 12 | tual
# Processing Record 44 of Set 12 | landskrona
# Processing Record 45 of Set 12 | matadi
# Processing Record 46 of Set 12 | opuwo
# Processing Record 47 of Set 12 | gabu
# Processing Record 48 of Set 12 | lexington park
# Processing Record 49 of Set 12 | manta
# Processing Record 50 of Set 12 | west caldwell
# Processing Record 1 of Set 13 | san borja
# Processing Record 2 of Set 13 | pokrovskoye
# Processing Record 3 of Set 13 | quilmana
# Processing Record 4 of Set 13 | dauphin
# Processing Record 5 of Set 13 | rumoi
# Processing Record 6 of Set 13 | vetlanda
# Processing Record 7 of Set 13 | tommot
# Processing Record 8 of Set 13 | nea alikarnassos
# Processing Record 9 of Set 13 | mastic beach
# Processing Record 10 of Set 13 | los llanos de aridane
# Processing Record 11 of Set 13 | hofn
# Processing Record 12 of Set 13 | massa marittima
# Processing Record 13 of Set 13 | leo
# Processing Record 14 of Set 13 | evensk
# Processing Record 15 of Set 13 | harper
# Processing Record 16 of Set 13 | margate
# Processing Record 17 of Set 13 | blora
# Processing Record 18 of Set 13 | balabac
# Processing Record 19 of Set 13 | zinder
# Processing Record 20 of Set 13 | uruzgan
# Processing Record 21 of Set 13 | umba
# Processing Record 22 of Set 13 | pilar
# Processing Record 23 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 13 | tezu
# Processing Record 25 of Set 13 | mandera
# Processing Record 26 of Set 13 | dunayivtsi
# City not found. Skipping...
# Processing Record 27 of Set 13 | tamiahua
# Processing Record 28 of Set 13 | kolondieba
# Processing Record 29 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 13 | warrington
# Processing Record 31 of Set 13 | wajima
# Processing Record 32 of Set 13 | khor
# Processing Record 33 of Set 13 | portland
# Processing Record 34 of Set 13 | palana
# Processing Record 35 of Set 13 | uyemskiy
# Processing Record 36 of Set 13 | tres arroyos
# Processing Record 37 of Set 13 | wattegama
# Processing Record 38 of Set 13 | ponta delgada
# Processing Record 39 of Set 13 | crestview
# Processing Record 40 of Set 13 | zhanaozen
# Processing Record 41 of Set 13 | san cristobal
# Processing Record 42 of Set 13 | wick
# Processing Record 43 of Set 13 | okhotsk
# Processing Record 44 of Set 13 | zabol
# Processing Record 45 of Set 13 | tecoanapa
# Processing Record 46 of Set 13 | sassandra
# Processing Record 47 of Set 13 | acapulco
# Processing Record 48 of Set 13 | garissa
# Processing Record 49 of Set 13 | rauma
# Processing Record 50 of Set 13 | kropotkin
# Processing Record 1 of Set 14 | kopargaon
# Processing Record 2 of Set 14 | kloulklubed
# Processing Record 3 of Set 14 | sokolovo
# Processing Record 4 of Set 14 | caxito
# Processing Record 5 of Set 14 | itaituba
# Processing Record 6 of Set 14 | akureyri
# Processing Record 7 of Set 14 | camargo
# Processing Record 8 of Set 14 | tretten
# Processing Record 9 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 10 of Set 14 | porto belo
# Processing Record 11 of Set 14 | muscat
# Processing Record 12 of Set 14 | carutapera
# Processing Record 13 of Set 14 | dulce nombre de culmi
# Processing Record 14 of Set 14 | lexington
# Processing Record 15 of Set 14 | yarada
# Processing Record 16 of Set 14 | vagur
# Processing Record 17 of Set 14 | jandayan
# Processing Record 18 of Set 14 | vila do maio
# Processing Record 19 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 20 of Set 14 | sampit
# Processing Record 21 of Set 14 | karimpur
# Processing Record 22 of Set 14 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 23 of Set 14 | amahai
# Processing Record 24 of Set 14 | gunjur
# Processing Record 25 of Set 14 | sarkand
# Processing Record 26 of Set 14 | yerbogachen
# Processing Record 27 of Set 14 | tiznit
# Processing Record 28 of Set 14 | wangkui
# Processing Record 29 of Set 14 | daugai
# Processing Record 30 of Set 14 | vanavara
# Processing Record 31 of Set 14 | amio
# Processing Record 32 of Set 14 | azrow
# City not found. Skipping...
# Processing Record 33 of Set 14 | puerto escondido
# Processing Record 34 of Set 14 | corlu
# Processing Record 35 of Set 14 | ugoofaaru
# Processing Record 36 of Set 14 | maceio
# Processing Record 37 of Set 14 | egvekinot
# Processing Record 38 of Set 14 | hualmay
# Processing Record 39 of Set 14 | shenjiamen
# Processing Record 40 of Set 14 | shubarshi
# Processing Record 41 of Set 14 | sicuani
# Processing Record 42 of Set 14 | luna
# Processing Record 43 of Set 14 | vokhma
# Processing Record 44 of Set 14 | price
# Processing Record 45 of Set 14 | hami
# Processing Record 46 of Set 14 | lazaro cardenas
# Processing Record 47 of Set 14 | sechura
# Processing Record 48 of Set 14 | denpasar
# Processing Record 49 of Set 14 | qixingtai
# Processing Record 50 of Set 14 | grafton
# Processing Record 1 of Set 15 | aldan
# Processing Record 2 of Set 15 | yinchuan
# Processing Record 3 of Set 15 | maldonado
# Processing Record 4 of Set 15 | sabang
# Processing Record 5 of Set 15 | balkanabat
# Processing Record 6 of Set 15 | arona
# Processing Record 7 of Set 15 | charyshskoye
# Processing Record 8 of Set 15 | walvis bay
# Processing Record 9 of Set 15 | likasi
# Processing Record 10 of Set 15 | eenhana
# Processing Record 11 of Set 15 | zaragoza
# Processing Record 12 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 15 | syasstroy
# Processing Record 14 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 15 | pangkalanbuun
# Processing Record 16 of Set 15 | salmo
# Processing Record 17 of Set 15 | certaldo
# Processing Record 18 of Set 15 | teeli
# Processing Record 19 of Set 15 | colquechaca
# Processing Record 20 of Set 15 | tingo maria
# Processing Record 21 of Set 15 | coracora
# Processing Record 22 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 23 of Set 15 | aquin
# Processing Record 24 of Set 15 | port hedland
# Processing Record 25 of Set 15 | alugan
# Processing Record 26 of Set 15 | gigmoto
# Processing Record 27 of Set 15 | sumbe
# Processing Record 28 of Set 15 | garowe
# Processing Record 29 of Set 15 | changping
# Processing Record 30 of Set 15 | ingleside
# Processing Record 31 of Set 15 | coquimbo
# Processing Record 32 of Set 15 | neverkino
# Processing Record 33 of Set 15 | kashin
# Processing Record 34 of Set 15 | pirovskoye
# Processing Record 35 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 15 | boffa
# Processing Record 37 of Set 15 | marfino
# Processing Record 38 of Set 15 | batemans bay
# Processing Record 39 of Set 15 | raudeberg
# Processing Record 40 of Set 15 | wanaka
# Processing Record 41 of Set 15 | snezhnogorsk
# Processing Record 42 of Set 15 | havelock
# Processing Record 43 of Set 15 | abeokuta
# Processing Record 44 of Set 15 | killybegs
# Processing Record 45 of Set 15 | touros
# Processing Record 46 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 47 of Set 15 | angoche
# Processing Record 48 of Set 15 | seoul
# Processing Record 49 of Set 15 | punta alta
# Processing Record 50 of Set 15 | acarau
# Processing Record 1 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 16 | nizhnevartovsk
# Processing Record 3 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 16 | jieshi
# Processing Record 5 of Set 16 | dakar
# Processing Record 6 of Set 16 | kapasan
# Processing Record 7 of Set 16 | conceicao do araguaia
# Processing Record 8 of Set 16 | maracai
# Processing Record 9 of Set 16 | kapiri mposhi
# Processing Record 10 of Set 16 | weihai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kalmunai   7.4167   81.8167     76.33        88          50
# 1    Punta Arenas -53.1500  -70.9167     51.91        50          75
# 2            Hilo  19.7297 -155.0900     78.12        58          83
# 3    Longyearbyen  78.2186   15.6401      8.44        61           0
# 4          Albany  42.6001  -73.9662     19.15        41          11
# 5         Ushuaia -54.8000  -68.3000     48.72        56          64
# 6  Ribeira Grande  38.5167  -28.7000     59.13        73          47
# 7          Atuona  -9.8000 -139.0333     78.08        77          11
# 8     Port Alfred -33.5906   26.8910     73.78        88          97
# 9         Rikitea -23.1203 -134.9692     76.55        69         100
#
#    Wind Speed Country Current Conditions                 Date
# 0        5.06      LK   scattered clouds  2022-01-30 22:04:17
# 1       23.02      CL      broken clouds  2022-01-30 22:04:17
# 2        5.01      US      broken clouds  2022-01-30 22:02:19
# 3       20.71      SJ          clear sky  2022-01-30 22:04:18
# 4        4.00      US         few clouds  2022-01-30 22:01:50
# 5        9.35      AR      broken clouds  2022-01-30 22:01:32
# 6       26.37      PT   scattered clouds  2022-01-30 22:04:19
# 7       13.69      PF         light rain  2022-01-30 22:02:49
# 8       17.18      ZA    overcast clouds  2022-01-30 22:04:19
# 9        4.16      PF    overcast clouds  2022-01-30 22:01:23

# %%
# Reorder the columns: City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed,
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Conditions"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0        Kalmunai      LK  2022-01-30 22:04:17   7.4167   81.8167     76.33
# 1    Punta Arenas      CL  2022-01-30 22:04:17 -53.1500  -70.9167     51.91
# 2            Hilo      US  2022-01-30 22:02:19  19.7297 -155.0900     78.12
# 3    Longyearbyen      SJ  2022-01-30 22:04:18  78.2186   15.6401      8.44
# 4          Albany      US  2022-01-30 22:01:50  42.6001  -73.9662     19.15
# 5         Ushuaia      AR  2022-01-30 22:01:32 -54.8000  -68.3000     48.72
# 6  Ribeira Grande      PT  2022-01-30 22:04:19  38.5167  -28.7000     59.13
# 7          Atuona      PF  2022-01-30 22:02:49  -9.8000 -139.0333     78.08
# 8     Port Alfred      ZA  2022-01-30 22:04:19 -33.5906   26.8910     73.78
# 9         Rikitea      PF  2022-01-30 22:01:23 -23.1203 -134.9692     76.55
#
#    Humidity  Cloudiness  Wind Speed Current Conditions
# 0        88          50        5.06   scattered clouds
# 1        50          75       23.02      broken clouds
# 2        58          83        5.01      broken clouds
# 3        61           0       20.71          clear sky
# 4        41          11        4.00         few clouds
# 5        56          64        9.35      broken clouds
# 6        73          47       26.37   scattered clouds
# 7        77          11       13.69         light rain
# 8        88          97       17.18    overcast clouds
# 9        69         100        4.16    overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
