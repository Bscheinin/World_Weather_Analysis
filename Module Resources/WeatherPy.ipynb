# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
#cities
# Out:
# 616

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yar-sale
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | burgeo
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | kamaishi
# Processing Record 11 of Set 1 | tateyama
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | perene
# Processing Record 14 of Set 1 | hay river
# Processing Record 15 of Set 1 | broken hill
# Processing Record 16 of Set 1 | beringovskiy
# Processing Record 17 of Set 1 | puerto ayacucho
# Processing Record 18 of Set 1 | wembley
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | port keats
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | kholtoson
# Processing Record 24 of Set 1 | saint-augustin
# Processing Record 25 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | doba
# Processing Record 29 of Set 1 | namatanai
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | shaunavon
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | goderich
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | tiznit
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | benghazi
# Processing Record 44 of Set 1 | turtkul
# City not found. Skipping...
# Processing Record 45 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 1 | kathmandu
# Processing Record 47 of Set 1 | sergeyevka
# Processing Record 48 of Set 1 | inuvik
# Processing Record 49 of Set 1 | port hardy
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | iqaluit
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | rosario
# Processing Record 6 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | nalut
# Processing Record 13 of Set 2 | sydney mines
# Processing Record 14 of Set 2 | rocha
# Processing Record 15 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | muros
# Processing Record 19 of Set 2 | grevena
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | jagatsinghapur
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | valparaiso
# Processing Record 24 of Set 2 | vazante
# Processing Record 25 of Set 2 | xuddur
# Processing Record 26 of Set 2 | bonavista
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | jutai
# Processing Record 34 of Set 2 | tres arroyos
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | meulaboh
# Processing Record 37 of Set 2 | sioux lookout
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | santa cruz
# Processing Record 40 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 2 | poum
# Processing Record 42 of Set 2 | ngunguru
# Processing Record 43 of Set 2 | naze
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | canchungo
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | canutama
# Processing Record 49 of Set 2 | necochea
# Processing Record 50 of Set 2 | acajutla
# Processing Record 1 of Set 3 | atherton
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | marzuq
# Processing Record 5 of Set 3 | xinzhi
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | itaueira
# Processing Record 9 of Set 3 | saint george
# Processing Record 10 of Set 3 | vila
# Processing Record 11 of Set 3 | bacolod
# Processing Record 12 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 3 | canar
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | bad doberan
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 3 | ambilobe
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 3 | hamilton
# Processing Record 22 of Set 3 | khandyga
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | cockburn town
# Processing Record 25 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | biga
# Processing Record 28 of Set 3 | peterhead
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | caohai
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | qaanaaq
# Processing Record 33 of Set 3 | tasiilaq
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | vila velha
# Processing Record 36 of Set 3 | vostok
# Processing Record 37 of Set 3 | saint-philippe
# Processing Record 38 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 3 | barstow
# Processing Record 40 of Set 3 | pangkalanbuun
# Processing Record 41 of Set 3 | ajdabiya
# Processing Record 42 of Set 3 | waingapu
# Processing Record 43 of Set 3 | faya
# Processing Record 44 of Set 3 | maragogi
# Processing Record 45 of Set 3 | atar
# Processing Record 46 of Set 3 | mungwi
# Processing Record 47 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 3 | northam
# Processing Record 49 of Set 3 | puerto madryn
# Processing Record 50 of Set 3 | itabirito
# Processing Record 1 of Set 4 | poli
# Processing Record 2 of Set 4 | juneau
# Processing Record 3 of Set 4 | hovd
# Processing Record 4 of Set 4 | margate
# Processing Record 5 of Set 4 | mbanza-ngungu
# Processing Record 6 of Set 4 | lata
# Processing Record 7 of Set 4 | tumpat
# Processing Record 8 of Set 4 | qunduz
# Processing Record 9 of Set 4 | kavaratti
# Processing Record 10 of Set 4 | sibu
# Processing Record 11 of Set 4 | shieli
# Processing Record 12 of Set 4 | sturgis
# Processing Record 13 of Set 4 | ugoofaaru
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | mehamn
# Processing Record 16 of Set 4 | kikwit
# Processing Record 17 of Set 4 | sosnovo-ozerskoye
# Processing Record 18 of Set 4 | codrington
# Processing Record 19 of Set 4 | castro
# Processing Record 20 of Set 4 | pangnirtung
# Processing Record 21 of Set 4 | labuhan
# Processing Record 22 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 4 | laguna
# Processing Record 24 of Set 4 | lahij
# Processing Record 25 of Set 4 | nouadhibou
# Processing Record 26 of Set 4 | bandarbeyla
# Processing Record 27 of Set 4 | brigantine
# Processing Record 28 of Set 4 | sola
# Processing Record 29 of Set 4 | bud
# Processing Record 30 of Set 4 | kiunga
# Processing Record 31 of Set 4 | college
# Processing Record 32 of Set 4 | wanderlandia
# City not found. Skipping...
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 4 | kingaroy
# Processing Record 36 of Set 4 | semirom
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | ukholovo
# Processing Record 39 of Set 4 | araripe
# Processing Record 40 of Set 4 | biltine
# Processing Record 41 of Set 4 | prince rupert
# Processing Record 42 of Set 4 | ferme-neuve
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | athabasca
# Processing Record 45 of Set 4 | arman
# Processing Record 46 of Set 4 | nanortalik
# Processing Record 47 of Set 4 | dingle
# Processing Record 48 of Set 4 | cianorte
# Processing Record 49 of Set 4 | uporovo
# Processing Record 50 of Set 4 | alofi
# Processing Record 1 of Set 5 | samarai
# Processing Record 2 of Set 5 | salalah
# Processing Record 3 of Set 5 | lompoc
# Processing Record 4 of Set 5 | coquimbo
# Processing Record 5 of Set 5 | boljoon
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | tevriz
# Processing Record 8 of Set 5 | saint-pierre
# Processing Record 9 of Set 5 | najran
# Processing Record 10 of Set 5 | arlit
# Processing Record 11 of Set 5 | isangel
# Processing Record 12 of Set 5 | kiruna
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | mwinilunga
# Processing Record 15 of Set 5 | mocuba
# Processing Record 16 of Set 5 | masaka
# Processing Record 17 of Set 5 | kargasok
# Processing Record 18 of Set 5 | guiren
# Processing Record 19 of Set 5 | lakes entrance
# Processing Record 20 of Set 5 | san patricio
# Processing Record 21 of Set 5 | te anau
# Processing Record 22 of Set 5 | kavieng
# Processing Record 23 of Set 5 | waitara
# Processing Record 24 of Set 5 | altay
# Processing Record 25 of Set 5 | sorland
# Processing Record 26 of Set 5 | tagusao
# Processing Record 27 of Set 5 | penzance
# Processing Record 28 of Set 5 | ostrovnoy
# Processing Record 29 of Set 5 | garachine
# Processing Record 30 of Set 5 | zhoucheng
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | chicontepec
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | teguldet
# Processing Record 35 of Set 5 | banjar
# Processing Record 36 of Set 5 | guamuchil
# Processing Record 37 of Set 5 | port macquarie
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | mount isa
# Processing Record 40 of Set 5 | ponta delgada
# Processing Record 41 of Set 5 | povenets
# Processing Record 42 of Set 5 | waipawa
# Processing Record 43 of Set 5 | ialibu
# Processing Record 44 of Set 5 | carlisle
# Processing Record 45 of Set 5 | muisne
# Processing Record 46 of Set 5 | susangerd
# Processing Record 47 of Set 5 | camacha
# Processing Record 48 of Set 5 | bogandinskiy
# Processing Record 49 of Set 5 | oistins
# Processing Record 50 of Set 5 | bardiyah
# Processing Record 1 of Set 6 | benton
# Processing Record 2 of Set 6 | jinka
# Processing Record 3 of Set 6 | mar del plata
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | svetlaya
# Processing Record 6 of Set 6 | warmbad
# Processing Record 7 of Set 6 | cabo san lucas
# Processing Record 8 of Set 6 | upata
# Processing Record 9 of Set 6 | prado
# Processing Record 10 of Set 6 | onega
# Processing Record 11 of Set 6 | unirea
# Processing Record 12 of Set 6 | algete
# Processing Record 13 of Set 6 | faanui
# Processing Record 14 of Set 6 | fort nelson
# Processing Record 15 of Set 6 | westport
# Processing Record 16 of Set 6 | port moresby
# Processing Record 17 of Set 6 | upernavik
# Processing Record 18 of Set 6 | canyon
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | kimbe
# Processing Record 21 of Set 6 | natal
# Processing Record 22 of Set 6 | abonnema
# Processing Record 23 of Set 6 | olinda
# Processing Record 24 of Set 6 | charters towers
# Processing Record 25 of Set 6 | revda
# Processing Record 26 of Set 6 | kirakira
# Processing Record 27 of Set 6 | port elizabeth
# Processing Record 28 of Set 6 | chapais
# Processing Record 29 of Set 6 | baruun-urt
# Processing Record 30 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 6 | tornio
# Processing Record 32 of Set 6 | saskylakh
# Processing Record 33 of Set 6 | foumban
# Processing Record 34 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 6 | kewanee
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | novosergiyevka
# Processing Record 38 of Set 6 | srednekolymsk
# Processing Record 39 of Set 6 | morondava
# Processing Record 40 of Set 6 | novo oriente
# Processing Record 41 of Set 6 | fuerte
# Processing Record 42 of Set 6 | camabatela
# Processing Record 43 of Set 6 | sabya
# Processing Record 44 of Set 6 | rio grande
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | ejea de los caballeros
# Processing Record 47 of Set 6 | barra do garcas
# Processing Record 48 of Set 6 | banjarmasin
# Processing Record 49 of Set 6 | tawau
# Processing Record 50 of Set 6 | champerico
# Processing Record 1 of Set 7 | moose factory
# Processing Record 2 of Set 7 | smirnykh
# Processing Record 3 of Set 7 | shellbrook
# Processing Record 4 of Set 7 | lingao
# Processing Record 5 of Set 7 | joshimath
# Processing Record 6 of Set 7 | kaeo
# Processing Record 7 of Set 7 | fortuna
# Processing Record 8 of Set 7 | mnogovershinnyy
# Processing Record 9 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 10 of Set 7 | baie-comeau
# Processing Record 11 of Set 7 | haines junction
# Processing Record 12 of Set 7 | den helder
# Processing Record 13 of Set 7 | zeya
# Processing Record 14 of Set 7 | winnemucca
# Processing Record 15 of Set 7 | shingu
# Processing Record 16 of Set 7 | nome
# Processing Record 17 of Set 7 | walvis bay
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | bethel
# Processing Record 20 of Set 7 | jipijapa
# Processing Record 21 of Set 7 | soyo
# Processing Record 22 of Set 7 | bilma
# Processing Record 23 of Set 7 | djibo
# Processing Record 24 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | kemijarvi
# Processing Record 27 of Set 7 | dali
# Processing Record 28 of Set 7 | young
# Processing Record 29 of Set 7 | portland
# Processing Record 30 of Set 7 | murmashi
# Processing Record 31 of Set 7 | nikolskoye
# Processing Record 32 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 7 | lebu
# Processing Record 34 of Set 7 | grand-santi
# Processing Record 35 of Set 7 | palmer
# Processing Record 36 of Set 7 | kampene
# Processing Record 37 of Set 7 | jining
# Processing Record 38 of Set 7 | cervo
# Processing Record 39 of Set 7 | lasa
# Processing Record 40 of Set 7 | mengyin
# Processing Record 41 of Set 7 | anloga
# Processing Record 42 of Set 7 | aksarka
# Processing Record 43 of Set 7 | owando
# Processing Record 44 of Set 7 | kasongo-lunda
# Processing Record 45 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 46 of Set 7 | shimoda
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | groningen
# Processing Record 49 of Set 7 | tiksi
# Processing Record 50 of Set 7 | suao
# City not found. Skipping...
# Processing Record 1 of Set 8 | padang
# Processing Record 2 of Set 8 | airai
# Processing Record 3 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 8 | broome
# Processing Record 5 of Set 8 | mmabatho
# Processing Record 6 of Set 8 | ancud
# Processing Record 7 of Set 8 | flinders
# Processing Record 8 of Set 8 | komsomolskiy
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | payakumbuh
# Processing Record 11 of Set 8 | punata
# Processing Record 12 of Set 8 | acapulco
# Processing Record 13 of Set 8 | khash
# Processing Record 14 of Set 8 | tingloy
# Processing Record 15 of Set 8 | tual
# Processing Record 16 of Set 8 | iranshahr
# Processing Record 17 of Set 8 | jumla
# Processing Record 18 of Set 8 | hornepayne
# Processing Record 19 of Set 8 | longyearbyen
# Processing Record 20 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 8 | tezu
# Processing Record 22 of Set 8 | karratha
# Processing Record 23 of Set 8 | yulara
# Processing Record 24 of Set 8 | fagersta
# Processing Record 25 of Set 8 | scarborough
# Processing Record 26 of Set 8 | lagoa
# Processing Record 27 of Set 8 | san quintin
# Processing Record 28 of Set 8 | liverpool
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | achit
# Processing Record 31 of Set 8 | arusha
# Processing Record 32 of Set 8 | nan
# Processing Record 33 of Set 8 | bairiki
# Processing Record 34 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 8 | bambous virieux
# Processing Record 36 of Set 8 | tuatapere
# Processing Record 37 of Set 8 | tabou
# Processing Record 38 of Set 8 | fairbanks
# Processing Record 39 of Set 8 | sidrolandia
# Processing Record 40 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 8 | roros
# Processing Record 42 of Set 8 | dossor
# Processing Record 43 of Set 8 | vao
# Processing Record 44 of Set 8 | huarmey
# Processing Record 45 of Set 8 | palana
# Processing Record 46 of Set 8 | islahiye
# Processing Record 47 of Set 8 | maraa
# Processing Record 48 of Set 8 | moindou
# Processing Record 49 of Set 8 | clyde river
# Processing Record 50 of Set 8 | vanavara
# Processing Record 1 of Set 9 | ivanivka
# Processing Record 2 of Set 9 | extrema
# Processing Record 3 of Set 9 | jizan
# Processing Record 4 of Set 9 | palmas
# Processing Record 5 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 6 of Set 9 | canon city
# Processing Record 7 of Set 9 | msanga
# Processing Record 8 of Set 9 | havre
# Processing Record 9 of Set 9 | freeport
# Processing Record 10 of Set 9 | sekoma
# Processing Record 11 of Set 9 | andenes
# Processing Record 12 of Set 9 | kahului
# Processing Record 13 of Set 9 | umm lajj
# Processing Record 14 of Set 9 | rockland
# Processing Record 15 of Set 9 | ende
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 9 | karpogory
# Processing Record 19 of Set 9 | gornyak
# Processing Record 20 of Set 9 | rawson
# Processing Record 21 of Set 9 | vung tau
# Processing Record 22 of Set 9 | nioro
# Processing Record 23 of Set 9 | kaseda
# Processing Record 24 of Set 9 | bundaberg
# Processing Record 25 of Set 9 | lorengau
# Processing Record 26 of Set 9 | delijan
# Processing Record 27 of Set 9 | adeje
# Processing Record 28 of Set 9 | sao jose da coroa grande
# Processing Record 29 of Set 9 | miri
# Processing Record 30 of Set 9 | konakovo
# Processing Record 31 of Set 9 | grand gaube
# Processing Record 32 of Set 9 | sakakah
# Processing Record 33 of Set 9 | ahipara
# Processing Record 34 of Set 9 | sinnamary
# Processing Record 35 of Set 9 | kuching
# Processing Record 36 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 9 | rantepao
# Processing Record 38 of Set 9 | mitsamiouli
# Processing Record 39 of Set 9 | orchard homes
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | safford
# Processing Record 42 of Set 9 | nuuk
# Processing Record 43 of Set 9 | olenegorsk
# Processing Record 44 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 9 | saint anthony
# Processing Record 46 of Set 9 | potgietersrus
# City not found. Skipping...
# Processing Record 47 of Set 9 | bima
# Processing Record 48 of Set 9 | madimba
# Processing Record 49 of Set 9 | hasaki
# Processing Record 50 of Set 9 | boteni
# Processing Record 1 of Set 10 | berevoesti
# Processing Record 2 of Set 10 | la seyne-sur-mer
# Processing Record 3 of Set 10 | maniitsoq
# Processing Record 4 of Set 10 | torbay
# Processing Record 5 of Set 10 | pacific grove
# Processing Record 6 of Set 10 | yurya
# City not found. Skipping...
# Processing Record 7 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 10 | xai-xai
# Processing Record 9 of Set 10 | erenhot
# Processing Record 10 of Set 10 | harper
# Processing Record 11 of Set 10 | san cristobal
# Processing Record 12 of Set 10 | ballina
# Processing Record 13 of Set 10 | coffs harbour
# Processing Record 14 of Set 10 | ulundi
# Processing Record 15 of Set 10 | iquitos
# Processing Record 16 of Set 10 | chiredzi
# Processing Record 17 of Set 10 | santa maria del rio
# Processing Record 18 of Set 10 | antofagasta
# Processing Record 19 of Set 10 | burica
# City not found. Skipping...
# Processing Record 20 of Set 10 | cherskiy
# Processing Record 21 of Set 10 | idukki
# Processing Record 22 of Set 10 | uzhur
# Processing Record 23 of Set 10 | alice springs
# Processing Record 24 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 10 | san francisco
# Processing Record 26 of Set 10 | taree
# Processing Record 27 of Set 10 | ixtapa
# Processing Record 28 of Set 10 | freetown
# Processing Record 29 of Set 10 | ahuimanu
# Processing Record 30 of Set 10 | sao sebastiao
# Processing Record 31 of Set 10 | huron
# Processing Record 32 of Set 10 | isiro
# Processing Record 33 of Set 10 | tiarei
# Processing Record 34 of Set 10 | chifeng
# Processing Record 35 of Set 10 | sarangani
# Processing Record 36 of Set 10 | janauba
# Processing Record 37 of Set 10 | sao joao da barra
# Processing Record 38 of Set 10 | raymond
# Processing Record 39 of Set 10 | codajas
# Processing Record 40 of Set 10 | jinan
# Processing Record 41 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 42 of Set 10 | petatlan
# Processing Record 43 of Set 10 | vila do maio
# Processing Record 44 of Set 10 | sonoita
# Processing Record 45 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 10 | lavrentiya
# Processing Record 47 of Set 10 | churapcha
# Processing Record 48 of Set 10 | boa vista
# Processing Record 49 of Set 10 | unguia
# Processing Record 50 of Set 10 | mackay
# Processing Record 1 of Set 11 | balykshi
# Processing Record 2 of Set 11 | port hedland
# Processing Record 3 of Set 11 | kirovskiy
# Processing Record 4 of Set 11 | macheng
# Processing Record 5 of Set 11 | orumiyeh
# Processing Record 6 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 11 | methoni
# Processing Record 8 of Set 11 | maceio
# Processing Record 9 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 10 of Set 11 | bloemfontein
# Processing Record 11 of Set 11 | krasyukovskaya
# Processing Record 12 of Set 11 | plouzane
# Processing Record 13 of Set 11 | bontang
# Processing Record 14 of Set 11 | waki
# Processing Record 15 of Set 11 | salym
# Processing Record 16 of Set 11 | kichera
# Processing Record 17 of Set 11 | aracaju
# Processing Record 18 of Set 11 | kharp
# Processing Record 19 of Set 11 | tamiahua
# Processing Record 20 of Set 11 | aripuana
# Processing Record 21 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 22 of Set 11 | pleshanovo
# Processing Record 23 of Set 11 | barras
# Processing Record 24 of Set 11 | korla
# Processing Record 25 of Set 11 | altamira
# Processing Record 26 of Set 11 | barranquilla
# Processing Record 27 of Set 11 | mae sot
# Processing Record 28 of Set 11 | yumen
# Processing Record 29 of Set 11 | bartica
# Processing Record 30 of Set 11 | comodoro rivadavia
# Processing Record 31 of Set 11 | porto santo
# Processing Record 32 of Set 11 | mogadishu
# Processing Record 33 of Set 11 | muli
# Processing Record 34 of Set 11 | novikovo
# Processing Record 35 of Set 11 | nova venecia
# Processing Record 36 of Set 11 | ulagan
# Processing Record 37 of Set 11 | vangaindrano
# Processing Record 38 of Set 11 | pismo beach
# Processing Record 39 of Set 11 | los llanos de aridane
# Processing Record 40 of Set 11 | alyangula
# Processing Record 41 of Set 11 | songjianghe
# Processing Record 42 of Set 11 | vardo
# Processing Record 43 of Set 11 | borzya
# Processing Record 44 of Set 11 | vanino
# Processing Record 45 of Set 11 | grahamstown
# Processing Record 46 of Set 11 | policoro
# Processing Record 47 of Set 11 | bhitarwar
# Processing Record 48 of Set 11 | hami
# Processing Record 49 of Set 11 | tamandare
# Processing Record 50 of Set 11 | uray
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | rongcheng
# Processing Record 3 of Set 12 | bam
# Processing Record 4 of Set 12 | hualmay
# Processing Record 5 of Set 12 | preston
# Processing Record 6 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 12 | cubuk
# Processing Record 8 of Set 12 | nantucket
# Processing Record 9 of Set 12 | amapa
# Processing Record 10 of Set 12 | kudat
# Processing Record 11 of Set 12 | tigil
# Processing Record 12 of Set 12 | ilulissat
# Processing Record 13 of Set 12 | pochutla
# Processing Record 14 of Set 12 | dudinka
# Processing Record 15 of Set 12 | kruisfontein
# Processing Record 16 of Set 12 | paraiso
# Processing Record 17 of Set 12 | beauly
# Processing Record 18 of Set 12 | road town
# Processing Record 19 of Set 12 | kovdor
# Processing Record 20 of Set 12 | barroso
# Processing Record 21 of Set 12 | port-cartier
# Processing Record 22 of Set 12 | gull lake
# Processing Record 23 of Set 12 | hirara
# Processing Record 24 of Set 12 | beni suef
# Processing Record 25 of Set 12 | rorvik
# Processing Record 26 of Set 12 | sangar
# Processing Record 27 of Set 12 | camapua
# Processing Record 28 of Set 12 | tambura
# Processing Record 29 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 12 | tautira
# Processing Record 31 of Set 12 | gaspe
# Processing Record 32 of Set 12 | ivanjica
# Processing Record 33 of Set 12 | vuktyl
# Processing Record 34 of Set 12 | ha tinh
# Processing Record 35 of Set 12 | clemson
# Processing Record 36 of Set 12 | san policarpo
# Processing Record 37 of Set 12 | tura
# Processing Record 38 of Set 12 | bubaque
# Processing Record 39 of Set 12 | kendari
# Processing Record 40 of Set 12 | oktyabrskiy
# Processing Record 41 of Set 12 | uyovu
# Processing Record 42 of Set 12 | canton
# Processing Record 43 of Set 12 | pimenta bueno
# Processing Record 44 of Set 12 | yeehaw junction
# City not found. Skipping...
# Processing Record 45 of Set 12 | hobyo
# Processing Record 46 of Set 12 | marabba
# Processing Record 47 of Set 12 | inirida
# Processing Record 48 of Set 12 | clonakilty
# Processing Record 49 of Set 12 | siyabuswa
# Processing Record 50 of Set 12 | mujiayingzi
# Processing Record 1 of Set 13 | benjamin constant
# Processing Record 2 of Set 13 | mayo
# Processing Record 3 of Set 13 | hailey
# Processing Record 4 of Set 13 | powell river
# Processing Record 5 of Set 13 | lyubokhna
# Processing Record 6 of Set 13 | neuquen
# Processing Record 7 of Set 13 | kyritz
# Processing Record 8 of Set 13 | alugan
# Processing Record 9 of Set 13 | colombo
# Processing Record 10 of Set 13 | sungaipenuh
# Processing Record 11 of Set 13 | timberlake
# Processing Record 12 of Set 13 | hambantota
# Processing Record 13 of Set 13 | soe
# Processing Record 14 of Set 13 | kirensk
# Processing Record 15 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 13 | capao bonito
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Yar-Sale  66.8333   70.8333     -0.54        96         100        8.63
# 1        Bluff -46.6000  168.3333     59.81        93          82        2.44
# 2       Burgeo  47.6167  -57.6152     32.09        77         100       45.95
# 3       Hobart -42.8794  147.3294     57.11        88           2        0.00
# 4       Touros  -5.1989  -35.4608     88.70        61          23       15.84
# 5      Rikitea -23.1203 -134.9692     76.15        60          74        4.81
# 6    Jamestown  42.0970  -79.2353     16.52        47          72        5.99
# 7  Tuktoyaktuk  69.4541 -133.0374     -2.20        78         100       16.11
# 8     Kamaishi  39.2667  141.8833     25.29        59          32        7.99
# 9     Tateyama  34.9833  139.8667     41.09        51         100       15.23
#
#   Country                 Date
# 0      RU  2022-01-30 16:15:02
# 1      NZ  2022-01-30 16:09:27
# 2      CA  2022-01-30 16:16:34
# 3      AU  2022-01-30 16:13:06
# 4      BR  2022-01-30 16:16:12
# 5      PF  2022-01-30 16:14:15
# 6      US  2022-01-30 16:14:14
# 7      CA  2022-01-30 16:16:35
# 8      JP  2022-01-30 16:16:36
# 9      JP  2022-01-30 16:16:36

# %%
# Reorder the columns: City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed,
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Yar-Sale      RU  2022-01-30 16:15:02  66.8333   70.8333     -0.54
# 1        Bluff      NZ  2022-01-30 16:09:27 -46.6000  168.3333     59.81
# 2       Burgeo      CA  2022-01-30 16:16:34  47.6167  -57.6152     32.09
# 3       Hobart      AU  2022-01-30 16:13:06 -42.8794  147.3294     57.11
# 4       Touros      BR  2022-01-30 16:16:12  -5.1989  -35.4608     88.70
# 5      Rikitea      PF  2022-01-30 16:14:15 -23.1203 -134.9692     76.15
# 6    Jamestown      US  2022-01-30 16:14:14  42.0970  -79.2353     16.52
# 7  Tuktoyaktuk      CA  2022-01-30 16:16:35  69.4541 -133.0374     -2.20
# 8     Kamaishi      JP  2022-01-30 16:16:36  39.2667  141.8833     25.29
# 9     Tateyama      JP  2022-01-30 16:16:36  34.9833  139.8667     41.09
#
#    Humidity  Cloudiness  Wind Speed
# 0        96         100        8.63
# 1        93          82        2.44
# 2        77         100       45.95
# 3        88           2        0.00
# 4        61          23       15.84
# 5        60          74        4.81
# 6        47          72        5.99
# 7        78         100       16.11
# 8        59          32        7.99
# 9        51         100       15.23

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
   
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                  Broken Hill
# Country                        AU
# Date          2022-01-30 16:16:37
# Lat                        -31.95
# Lng                      141.4333
# Max Temp                    81.27
# Humidity                       58
# Cloudiness                     91
# Wind Speed                   9.57
# Name: 13, dtype: object

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,-20))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-1.3829014295195572, intercept=92.55867975052243, rvalue=-0.8686610915133849, pvalue=6.519982638167682e-115, stderr=0.041001709758907406, intercept_stderr=1.7867563098002435)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,80))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.28965426841084885, intercept=81.63221686828565, rvalue=0.4319875458682032, pvalue=4.867286666812759e-10, stderr=0.04410403572300434, intercept_stderr=1.053199489690171)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.4713603190581092, intercept=52.05670189855487, rvalue=0.4235113048485976, pvalue=1.2692899075602117e-17, stderr=0.052415895204215114, intercept_stderr=2.2841591738650298)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-30,25))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.20021040126588344, intercept=78.78586649176887, rvalue=0.14767783174140459, pvalue=0.0420193985994055, stderr=0.09779221719632292, intercept_stderr=2.3352673187029094)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.5382059054410678, intercept=37.05840308864522, rvalue=0.27530801245443814, pvalue=6.787032110505452e-08, stderr=0.0977041519556856, intercept_stderr=4.257712935070418)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,25))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=1.0148466432065968, intercept=89.44642935030302, rvalue=0.3885796641321347, pvalue=3.022609896807197e-08, stderr=0.17550793901558312, intercept_stderr=4.1911101507514)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.016198385369999665, intercept=7.991352870586745, rvalue=0.04728150079950212, pvalue=0.36315368885599897, stderr=0.01779072418179542, intercept_stderr=0.7752771500177021)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,20))

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-0.1713180331318617, intercept=5.683830372291254, rvalue=-0.36018140298236867, pvalue=3.319156326696265e-07, stderr=0.03236157988277029, intercept_stderr=0.7727909443970415)
